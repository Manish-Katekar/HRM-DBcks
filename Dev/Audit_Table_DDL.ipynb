-- %%
CREATE TABLE IF NOT EXISTS `dev-catalog`.`audit`.`load_logs` (
    id BIGINT GENERATED ALWAYS AS IDENTITY,
    data_source STRING,
    tablename STRING,
    numberofrowscopied INT,
    watermarkcolumnname STRING,
    loaddate TIMESTAMP
);

-- %%
drop table  `dev-catalog`.`audit`.`load_logs`

-- %%
SELECT * FROM `dev-catalog`.`audit`.`load_logs` order by loaddate
