# %%
# %sql
CREATE TABLE IF NOT EXISTS `dev-catalog`.`gold`.`dim_npi_extract` (
  npi_id STRING,
  first_name STRING,
  last_name STRING,
  position STRING,
  organisation_name STRING,
  last_updated STRING,
  refreshed_at TIMESTAMP)

# %%
# %sql
truncate table `dev-catalog`.`gold`.`dim_npi_extract`

# %%
# %sql
insert into
  `dev-catalog`.`gold`.`dim_npi_extract` 
select
  npi_id,
  first_name,
  last_name,
  position,
  organisation_name,
  last_updated,
  current_timestamp()
from
  `dev-catalog`.`silver`.`npi_extract` 
  where is_current_flag = true
