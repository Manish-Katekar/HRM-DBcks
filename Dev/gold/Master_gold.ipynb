# %%
dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/gold/dim_cptcodes_gold",
    timeout_seconds=0
)

dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/gold/dim_departments_gold",
    timeout_seconds=0
)

dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/gold/dim_icd_codes_gold",
    timeout_seconds=0
)

dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/gold/dim_npi_extract_gold",
    timeout_seconds=0
)

dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/gold/dim_patients_gold",
    timeout_seconds=0
)
dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/gold/dim_providers_gold",
    timeout_seconds=0
)

dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/gold/fact_transactions_gold",
    timeout_seconds=0
)
