# %%
dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/silver/Claims_silver",
    timeout_seconds=0
)

dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/silver/CPT codes_silver",
    timeout_seconds=0
)

dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/silver/Departments_F_silver",
    timeout_seconds=0
)

dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/silver/Encounters_silver",
    timeout_seconds=0
)

dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/silver/ICD Code_silver",
    timeout_seconds=0
)
dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/silver/NPI_silver",
    timeout_seconds=0
)

dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/silver/Patients_silver",
    timeout_seconds=0
)

dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/silver/Providers_F_silver",
    timeout_seconds=0
)

dbutils.notebook.run(
    "/Workspace/Users/mankatekar@gmail.com/HRM-DBcks/Dev/silver/Transactions_silver",
    timeout_seconds=0
)
